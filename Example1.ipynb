# %%
#a simple program that adds two numbers together and prints the result
num1 = 5
num2 = 3
result = num1 + num2
print("The sum of", num1, "and", num2, "is", result)
# Out:
# The sum of 5 and 3 is 8
